# %% [markdown]
# # Vacunación por el Covid-19 en Argentina
# ___
#
# ### Conclusion
# La conclusion que podemos obtener en base a los graficos es que la vacunacion de las primeras dosis,
# se le dio mas prioridad a las personas con las edades mas bajas hasta los 40 años,
# y en cuanto a la segunda, se priorizaron las personas entre 51 y 80 años.

# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("dataset_total_vacunas.csv",sep=",",engine="python" )

#grafico = sns.pairplot(df1,hue="VACUNA",palette="Spectral")

df2 = df1[["GRUPO_ETARIO","DOSIS_1", "DOSIS_2"]]
grafico = sns.pairplot(df2,hue="GRUPO_ETARIO",palette="Spectral")
